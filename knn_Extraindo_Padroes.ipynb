# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

sns.set()

# %%
dados = pd.read_csv('CC GENERAL.csv', sep = ',')

# %%
dados.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
dados.shape
# Out:
# (8950, 18)

# %%
dados.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
dados.isna().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %% [markdown]
# As colunas CUST_ID e TENURE não trazem informações relevates. Por conta disso serão exluidas do DataFrame

# %%
dados.drop(['CUST_ID','TENURE'], axis= 1, inplace= True)

# %%
dados.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %% [markdown]
# ### **Tratando dados faltantes**
#
# Podemos ver que a coluna MINIMUM_PAYMENTS possui vários dados faltantes. Para preencher estes dados, ferei o calculo da mediana, pegarei este valor e atribuirei a os dados que estão faltando na base de dados.

# %%
mediana = dados['MINIMUM_PAYMENTS'].median()
dados.loc[dados['MINIMUM_PAYMENTS'].isnull(), 'MINIMUM_PAYMENTS'] = mediana
dados.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        1
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# dtype: int64

# %% [markdown]
# Outra coluna que apresenta Dados Faltantes é a coluna CREDIT_LIMIT
#
# Neste caso, farei o preenchimento com o Fillna tambem com os dados da mediana

# %%
dados.fillna(dados['CREDIT_LIMIT'].median(), inplace= True)
dados.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# dtype: int64

# %% [markdown]
# ## Normalizando os Dados

# %%
from sklearn.preprocessing import Normalizer
normalizar = Normalizer()

dados_normalizados = normalizar.fit_transform(dados)

# %%
dados_normalizados
# Out:
# array([[3.93555441e-02, 7.87271593e-04, 9.17958473e-02, ...,
#         1.94178127e-01, 1.34239194e-01, 0.00000000e+00],
#        [2.93875903e-01, 8.34231560e-05, 0.00000000e+00, ...,
#         3.76516684e-01, 9.84037959e-02, 2.03923046e-05],
#        [3.10798149e-01, 1.24560965e-04, 9.63068011e-02, ...,
#         7.74852335e-02, 7.81351982e-02, 0.00000000e+00],
#        ...,
#        [2.27733092e-02, 8.11060955e-04, 1.40540698e-01, ...,
#         7.90986945e-02, 8.02156174e-02, 2.43318384e-04],
#        [2.65257948e-02, 1.64255731e-03, 0.00000000e+00, ...,
#         1.03579625e-01, 1.09898221e-01, 4.92767391e-04],
#        [1.86406219e-01, 3.33426837e-04, 5.46778061e-01, ...,
#         3.15915455e-02, 4.41568390e-02, 0.00000000e+00]])

# %% [markdown]
# ## Montando o Cluster

# %% [markdown]
# Aqui, apliquei o modelo e já salvei o grupo dentro de uma coluna no DataFrame original
#
# Com isso, ganho tempo para fazer uma análise mais refinada ou mais aprofundada.

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters= 5, n_init= 10, max_iter= 300)

dados['cluster'] = kmeans.fit_predict(dados_normalizados)

# %%
dados
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
dados.groupby(['cluster']).describe()
# Out:
#         BALANCE                                                                \
#           count         mean          std       min          25%          50%
# cluster
# 0        3279.0   445.745630   848.204793  0.000000    23.340435    83.148283
# 1        2659.0  3218.841621  7464.365790  6.824905  1250.690719  2159.370933
# 2        1544.0  1142.091637  1659.735979  0.000000   212.178230   556.818403
# 3        1073.0  1808.060494  1999.653729  0.000000   507.076999  1096.517209
# 4         395.0  1984.529708  1851.265375  1.045584  1007.928213  1322.647480
#
#                                     BALANCE_FREQUENCY             ...  \
#                  75%            max             count       mean  ...
# cluster                                                           ...
# 0         415.914670    9630.367575            3279.0   5.039451  ...
# 1        4225.343295  311357.000000            2659.0  11.624755  ...
# ...

# %%
centroides = kmeans.cluster_centers_

print(f'Quantidade de Centroides {len(centroides[0])}')
# Out:
# Quantidade de Centroides 16

# %%
max = len(centroides[0])
item = []
valor = []

for i in range(max):
    item.append(dados.columns.values[i])
    valor.append(centroides[:, i].var())

pd.options.display.float_format = '{:.2f}'.format

resultados = pd.DataFrame({'Item':item, 'Valor': valor})
resultados= resultados.sort_values(by= 'Valor', ascending= False)
resultados
# Out:
#                                 Item  Valor
# 14                  MINIMUM_PAYMENTS   0.06
# 12                      CREDIT_LIMIT   0.04
# 13                          PAYMENTS   0.03
# 5                       CASH_ADVANCE   0.02
# 0                            BALANCE   0.02
# 2                          PURCHASES   0.02
# 3                   ONEOFF_PURCHASES   0.01
# 4             INSTALLMENTS_PURCHASES   0.00
# 11                     PURCHASES_TRX   0.00
# 8   PURCHASES_INSTALLMENTS_FREQUENCY   0.00
# 15                  PRC_FULL_PAYMENT   0.00
# 1                  BALANCE_FREQUENCY   0.00
# 6                PURCHASES_FREQUENCY   0.00
# 10                  CASH_ADVANCE_TRX   0.00
# 7         ONEOFF_PURCHASES_FREQUENCY   0.00
# 9             CASH_ADVANCE_FREQUENCY   0.00

# %%
itens = resultados[1:6].head()['Item'].values.tolist()
itens
# Out:
# ['CREDIT_LIMIT', 'PAYMENTS', 'CASH_ADVANCE', 'BALANCE', 'PURCHASES']

# %%
description= dados.groupby(['cluster'])[itens]
n_clients = description.size()
description = description.mean()
description['n_clientes']= n_clients
description.sort_values(by = 'n_clientes', ascending= False)
# Out:
#          CREDIT_LIMIT  PAYMENTS  CASH_ADVANCE  BALANCE  PURCHASES  n_clientes
# cluster
# 0             5129.34    813.21        145.08   445.75     627.53        3279
# 1             4478.73    970.99       1624.94  3218.84     389.41        2659
# 2             4082.91   3026.77        185.60  1142.09    3252.74        1544
# 3             4010.88  35338.86      22384.76  1808.06     492.59        1073
# 4             2248.35   1348.31        431.38  1984.53     847.57         395

# %% [markdown]
# ### **Analisando os Clusters**

# %% [markdown]
# <b>CLUSTER 0</b>: Clientes que gastam pouco. Clientes com maior limite. Bons pagadores. Maior Nuemro de Clientes</P>
# CLUSTER 1: Clientes que mais gastam e com foco em saque. Piores pagadores. Boa quantidade de clientes</p>
# CLUSTER 2: Cleintes que gastam muito com compras. Melhores Pagadores</p>
# CLUSTER 3: Clientes que gastam muito com saques. Pagam as vezes</p>
# CLUSTER 4: Clientes com menor Limite de Crédito. Não são bons pagadores. Menor quantidade de Clientes
